# %%
celsium = int(input("Температура в цельсиях: "))
farenheit=(celsium*9/5)+ 2
print(farenheit)

# %%
n=input('Имя: ')
s=input('Фамилия: ')
print(n+' '+s)

# %%
a=int(input())
b=int(input())
print(a*b)

# %%
a=10
b=3
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a**b)

# %%
print(len(input()))

# %%
num=int(input())%2
print('не'*num + 'чётное')

# %%
word=input()
u=int(input())
print(word*u)

# %%
minut=int(input())
print(minut//60+' ч'+minut%60+' мин')

# %%
a=int(input())
b=int(input())
c=int(input())
p=(a+b+c)/2
print((p*(p-a)*(p-b)*(p-c))**0.5)

# %%
print(input()[:3])

# %%
print(input()[::-1])

# %%
les=input()
gef=input()
dig=int(gef in les)
ndig= not dig
print("Да, подстрока найдена!"*dig + "Нет, подстрока не найдена!"*ndig)

# %%
les=input()
print(les.replace('Python', 'JavaScript'))

# %%
les=input()
print(*les.split(","))

# %%
les=input()
kel=input()
h=les.find(kel)
print("Символ "+kel+"встречается "+h+" раз")

# %%
les=input()
print(les.strip())

# %%
les=input()
print(''.join(filter(str.isdigit(), s)))

# %%
les=input()
a=les[:3]
les=les[3:]
b=les[:3]
les=les[3:]
c=les[:3]
les=les[3:]
d=les[:2]
les=les[2:]
print(a+' ('+b+') '+c+'-'+d+'-'+les)

# %%
s = input()
k = int(input())
alphabet = 'abcdefghijklmnopqrstuvwxyz'
shifted = alphabet[k % 26:] + alphabet[:k % 26]
print(s.translate(str.maketrans(alphabet, shifted)))
